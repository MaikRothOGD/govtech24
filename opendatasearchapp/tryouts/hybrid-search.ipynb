# %% [markdown]
# # Imports

# %%
import pandas as pd

pd.options.mode.chained_assignment = None
pd.options.display.max_rows = 500
pd.options.display.max_seq_items = 500

import numpy as np
import requests
import json
import re
import time
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup as bs4

from sentence_transformers import SentenceTransformer, util
from sentence_transformers.util import semantic_search


import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# # Constants

# %%
BASELINK_DATAPORTAL = "https://opendata.swiss/de/dataset/"
CKAN_API_LINK = (
    "https://ckan.opendata.swiss/api/3/action/current_package_list_with_resources"
)

LANGUAGE = "de"

# %%
semantic_cols = [
    "title.de",
    "title.fr",
    "title.it",
    "title.en",
    "description.de",
    "description.fr",
    "description.it",
    "description.en",
    "tags",
    "keywords.de",
    "keywords.fr",
    "keywords.it",
    "keywords.en",
]

final_cols = semantic_cols + ["id", "organization.title", "organization.url"]

# %% [markdown]
# # Functions

# %%
def get_full_package_list(limit=500, sleep=2):
    """Get full package list from CKAN API"""
    offset = 0
    frames = []
    while True:
        print(f"{offset} packages retrieved.")
        url = CKAN_API_LINK + f"?limit={limit}&offset={offset}"
        res = requests.get(url)
        data = json.loads(res.content)
        if data["result"] == []:
            break
        data = pd.DataFrame(pd.json_normalize(data["result"]))
        frames.append(data)
        offset += limit
        time.sleep(sleep)
    data = pd.concat(frames)
    data = data.reset_index(drop=True)
    return data


def clean_features(data):
    """Clean various features"""
    # Reduce publisher data to name.
    data.publisher = data.publisher.apply(lambda x: json.loads(x)["name"])

    # Reduce tags to tag names.
    data.tags = data.tags.apply(lambda x: [tag["name"] for tag in x])

    # Replace empty urls with NA message.
    data[data["organization.url"] == ""]["organization.url"] = "None provided"

    # Remove HTML tags from description.
    data[f"description.{LANGUAGE}"] = data[f"description.{LANGUAGE}"].apply(
        lambda x: bs4(x, "html.parser").text
    )

    # Strip whitespace from title.
    data[f"title.{LANGUAGE}"] = data[f"title.{LANGUAGE}"].map(lambda x: x.strip())

    return data

# %% [markdown]
# # Create starter code files and README

# %% [markdown]
# **Get all metadata packages from CKAN API**

# %%
# all_packages = get_full_package_list()
# all_packages.to_parquet(f"metadata_240314.parq", engine="fastparquet")

# %% [markdown]
# **Reload data from disk and clean**

# %%
df = pd.read_parquet(f"metadata_240314.parq", engine="fastparquet")

# Reduce tags to text
df.tags = df.tags.apply(lambda x: x[0]["name"] if x not in [None, []] else "")

# Reduce keywords to text
for feature in ["keywords.fr", "keywords.de", "keywords.en", "keywords.it"]:
    df[feature] = df[feature].apply(
        lambda x: ", ".join(x) if x not in [None, []] else ""
    )

# Reduce all text features to one column
df["joined"] = df[semantic_cols].apply(lambda row: " ".join(row.astype(str)), axis=1)

# Create link from base link and name
df["link"] = df.name.apply(lambda x: BASELINK_DATAPORTAL + x)

# %%
def clean_text(text):
    """Clean text"""
    # Remove line breaks \n \r etc
    text = re.sub(r"\s+", " ", text)
    # Remove square and round brackets
    text = re.sub(r"\[.*?\]", " ", text)
    text = re.sub(r"\(.*?\)", " ", text)
    # Remove " and '
    text = text.replace('"', " ")
    text = text.replace("'", " ")
    # Replace hypens with space
    text = text.replace("-", " ")
    text = text.replace("–", " ")
    # Remove punctuation but keep dots
    text = re.sub(r"[^\w\s.]", "", text)
    # Remove multiple spaces
    text = re.sub(" +", " ", text)
    # Remove leading and trailing whitespace
    text = text.strip()
    return text


df.joined = df.joined.apply(clean_text)

# %%
empties = df[df["title.de"] == ""].index
df.loc[empties, "title.de"] = df.loc[empties, "title.en"]

empties = df[df["title.de"] == ""].index
df.loc[empties, "title.de"] = df.loc[empties, "title.fr"]

empties = df[df["title.de"] == ""].index
df.loc[empties, "title.de"] = df.loc[empties, "title.it"]

empties = df[df["title.de"] == ""].index
len(empties)
# Out:
# 0

# %%
df.to_parquet(f"metadata_240314_cleaned.parq", engine="fastparquet")

# %%
df.head(1).T
# Out:
#                                                                                 0
# owner_org                                    ec2593fa-d844-4d20-9851-e3c2b24eff89
# maintainer                      Bundesamt für Gesundheit, Sektion Datenmanagem...
# issued                                                        2024-03-14T00:00:00
# title_for_slug                  Qualitätsindikatoren der Schweizer Akutspitäle...
# qualified_relations                                                            []
# private                                                                     False
# maintainer_email                                             KUV-DMS@bag.admin.ch
# num_tags                                                                       32
# contact_points                  [{'name': 'Bundesamt für Gesundheit, Sektion D...
# temporals                       [{'start_date': '2022-01-01T00:00:00', 'end_da...
# id                                           25505566-e94b-449d-8d93-e7dec6b5e898
# metadata_created                                       2024-03-07T10:57:50.018541
# conforms_to                                                                    []
# metadata_modified                                      2024-03-14T11:31:13.837093
# author                                                                       None
# author_email                                                                 None
# relations                       [{'url': 'https://www.admin.ch/opc/de/classifi...
# state                                                                      active
# version                                                                      None
# relationships_as_object                                                        []
# license_id                                                                   None
# type                                                                      dataset
# resources                       [{'documentation': [], 'cache_last_updated': N...
# scheduled
# num_resources                                                                  10
# tags                                                         acute-care-hospitals
# language                                                             [de, fr, it]
# groups                          [{'display_name': {'fr': 'Santé', 'de': 'Gesun...
# creator_user_id                              0594d621-c92a-4a32-809c-98e281dc7944
# relationships_as_subject                                                       []
# license_title                                                                None
# publisher                       {"url": "https://opendata.swiss/organization/b...
# name                            qualitatsindikatoren-der-schweizer-akutspitale...
# isopen                                                                      False
# accrual_periodicity             http://publications.europa.eu/resource/authori...
# documentation                                                                  []
# modified                                                      2024-03-14T00:00:00
# url                                                  http://www.bag.admin.ch/qiss
# see_alsos                                                                      []
# revision_id                                  6766fc50-21ad-4416-bd3d-ebb7cfe95253
# identifier                                     qip22@bundesamt-fur-gesundheit-bag
# keywords.fr                     hopitaux-de-soins-aigus, office-federal-de-la-...
# keywords.de                     kvg, medizinische-statistik, fallzahlen, bag, ...
# keywords.en                     federal-office-of-public-health, health-insura...
# keywords.it                     tassi-di-mortalita, lamal, numero-di-casi, ufs...
# description.fr                  Les indicateurs de qualité des hôpitaux suisse...
# description.en                  The quality indicators of the Swiss acute care...
# description.de                  Die Qualitätsindikatoren der Schweizer Akutspi...
# description.it                  Gli indicatori di qualità degli ospedali per c...
# title.fr                        Indicateurs de qualité des hôpitaux suisses de...
# title.de                        Qualitätsindikatoren der Schweizer Akutspitäle...
# title.en                        Quality indicators of the Swiss acute care hos...
# title.it                        Indicatori di qualità degli ospedali per cure ...
# organization.display_name.fr             Office fédéral de la santé publique OFSP
# organization.display_name.de                         Bundesamt für Gesundheit BAG
# organization.display_name.en                 Federal Office of Public Health FOPH
# organization.display_name.it          Ufficio federale della sanità pubblica UFSP
# organization.description.fr     L'Office fédéral de la santé publique (OFSP) f...
# organization.description.de     Das Bundesamt für Gesundheit (BAG) ist Teil de...
# organization.description.en     The Federal Office of Public Health (FOPH) is ...
# organization.description.it     L'Ufficio federale della sanità pubblica (UFSP...
# organization.created                                   2015-11-30T11:08:41.426558
# organization.url
# organization.package_count                                                     41
# organization.image_display_url  https://ckan.opendata.swiss/uploads/group/BAG-...
# organization.approval_status                                             approved
# organization.id                              ec2593fa-d844-4d20-9851-e3c2b24eff89
# organization.is_organization                                                 True
# organization.state                                                         active
# organization.image_url          https://ckan.opendata.swiss/uploads/group/BAG-...
# organization.groups                                                            []
# organization.title.fr                    Office fédéral de la santé publique OFSP
# organization.title.de                                Bundesamt für Gesundheit BAG
# organization.title.en                        Federal Office of Public Health FOPH
# organization.title.it                 Ufficio federale della sanità pubblica UFSP
# organization.revision_id                     05c2a73e-d135-4267-bc50-4f29250c21c6
# organization.num_followers                                                      0
# organization.type                                                    organization
# organization.political_level                                        confederation
# organization.tags                                                              []
# organization.name                                    bundesamt-fur-gesundheit-bag
# extras                                                                       None
# spatial                                                                      None
# description.rm                                                               None
# title.rm                                                                     None
# coverage                                                                     None
# display_name.fr                                                              None
# display_name.de                                                              None
# display_name.en                                                              None
# display_name.it                                                              None
# joined                          Qualitätsindikatoren der Schweizer Akutspitäle...
# link                            https://opendata.swiss/de/dataset/qualitatsind...

# %% [markdown]
# # Embed texts

# %%
df = pd.read_parquet(f"metadata_240314_cleaned.parq", engine="fastparquet")

# %%
# model_path = "all-MiniLM-L6-v2"
# model_path = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
# model_path = "distiluse-base-multilingual-cased-v2"
# model_path = "jinaai/jina-embeddings-v2-base-de"
# model = SentenceTransformer(model_path, device="mps")

# Encoding with the Nomic model without a CUDA device takes very long.
model = SentenceTransformer(
    "nomic-ai/nomic-embed-text-v1.5", 
    trust_remote_code=True, 
    device="mps" # Only for Mac with Apple Silicon, otherwise remove this line
)
print(f"{model.max_seq_length}")

embeddings = model.encode(
    df.joined.values,
    batch_size=128,
    show_progress_bar=True,
    normalize_embeddings=True,
)

# Save embeddings with numpy.save
np.save("embeddings_nomic.npy", embeddings)
# Out:
# <All keys matched successfully>
# 8192

# %%
with open("embeddings_nomic.npy", "rb") as f:
    embeddings = np.load(f)

# %%
search_term = "velo"
query_embedding = model.encode(
    search_term, show_progress_bar=True, device="mps", normalize_embeddings=True
)
hits = util.semantic_search(query_embedding, embeddings, top_k=50)
hits = hits[0]
for hit in hits:
    print(
        df.iloc[hit["corpus_id"]]["title.de"],
        "(Score: {:.4f})".format(hit["score"], df.iloc[hit["corpus_id"]]["link"]),
    )
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Velonetz (WFS) (Score: 0.6761)
# Velonetz (WMS) (Score: 0.6761)
# Velo (Score: 0.6554)
# Velo-Fahrverbote (allgemein oder temporär) (Score: 0.6376)
# Velopumpen (Score: 0.6372)
# Velostrassen (Score: 0.6332)
# Velo-Themen (Score: 0.6317)
# Velo-Schlauchautomaten (Score: 0.6294)
# Velo-Einbahnstrassen und -Gefahrenstellen (Score: 0.6276)
# Teilrichtplan Velo (Score: 0.6273)
# Velopumpen (Score: 0.6234)
# Steile Velo-Strecken (Score: 0.6158)
# Veloplan Stadt St.Gallen (Score: 0.6146)
# Velonetz (Score: 0.6145)
# Velopumpen - Standort und Informationen (Score: 0.6141)
# Veloabstellplätze (Score: 0.6089)
# Veloverleih (Score: 0.6057)
# Velopumpenstandorte (Score: 0.6047)
# Velo- und Motorradabstellplätze in der Stadt St.Gallen (Score: 0.6004)
# Touristische Velorouten (Score: 0.5981)
# Velopumpen - Standort und Informationen (WMS) (Score: 0.5972)
# Velopumpen - Standort und Informationen (WFS) (Score: 0.5972)
# Velostadtplan (Score: 0.5933)
# Verkehrsreiche Strassen (50 km/h oder mehr) (Score: 0.5890)
# Velopumpen (Score: 0.5828)
# Veloprüfstrecken (Score: 0.5828)
# Masterplan Velo (Score: 0.5797)
# Inline-Skating-Routen (Score: 0.5789)
# Veloanlagen: Radwegen (Score: 0.5754)
# Velowegnetze für die Freizeit (Score: 0.5754)
# Verkehrszähldaten (Score: 0.5748)
# Verkehrsmessstellen (Score: 0.5690)
# Velozählungen Stadt St.Gallen ab 2016 (Score: 0.5674)
# Länge der National-, Kantons- und übrigen dem Motorfahrzeugverkehr geöffneten Strassen (Score: 0.5642)
# Freizeitverkehr - Mountainbike-Pisten (Score: 0.5642)
# Verkehrszählstellen (Score: 0.5640)
# Velozählungen Stadt St.Gallen - Archiv (2011 - 2015) (Score: 0.5632)
# Langsamverkehr - Veloland Schweiz (Score: 0.5629)
# CARTE VELO (Score: 0.5619)
# WFS Velonetz (Score: 0.5613)
# WMS Velonetz (Score: 0.5603)
# VBZ-Verkaufsstelle (Score: 0.5570)
# Fahrzeuge und Transportmittelbestände des Personenverkehrs (Score: 0.5551)
# Fahrleistungen und Fahrzeugbewegungen im Personenverkehr (Score: 0.5548)
# Kenngrössenmatrizen der Nachfrage 2017 (Score: 0.5545)
# Länge der National-, Kantons- und übrigen dem Motorfahrzeugverkehr geöffneten Strassen nach Kanton (Score: 0.5543)
# Veloparkierung (Score: 0.5527)
# Verkehrszähler (Strassenverkehr) - Echtzeit (Score: 0.5526)
# Geokoordinaten Velo Zählstellen Stadt St.Gallen (Score: 0.5479)
# Standorte ZüriVelo (Score: 0.5450)

# %% [markdown]
# # Call CKAN search endpoint

# %%
def call_ckan(query, limit=100):
    """Call CKAN API to search for query"""
    url = f"https://opendata.swiss/api/3/action/package_search?q={query}&rows={limit}"
    res = requests.get(url)
    data = json.loads(res.content)
    return data["result"]["results"]

# %%
query = "Bevölkerung"
url = f"https://ckan.opendata.swiss/api/3/action/package_search?q={query}&facet.limit=100&rows=100"

# %%
results[0]
# Out:
# {'owner_org': 'bc3fde05-b0bf-4035-a098-a2d6f89d47c3',
#  'maintainer': 'stata@bs.ch',
#  'groups': [{'display_name': {'fr': 'Population et société',
#     'de': 'Bevölkerung und Gesellschaft',
#     'en': 'Population and society',
#     'it': 'Popolazione e società'},
#    'description': {'fr': '', 'de': '', 'en': '', 'it': ''},
#    'title': '{"de": "Bevölkerung und Gesellschaft", "en": "Population and society", "fr": "Population et société", "it": "Popolazione e società"}',
#    'image_display_url': '',
#    'id': 'd569c3de-4b8d-4de0-8f0e-9ac4c17f9003',
#    'name': 'soci'},
#   {'display_name': {'fr': 'Éducation, culture et sport',
#     'de': 'Bildung, Kultur und Sport',
#     'en': 'Education, culture and sport',
#     'it': 'Istruzione, cultura e sport'},
#    'description': {'fr': '', 'de': '', 'en': '', 'it': ''},
#    'title': '{"de": "Bildung, Kultur und Sport", "en": "Education, culture and sport", "fr": "Éducation, culture et sport", "it": "Istruzione, cultura e sport"}',
#    'image_display_url': '',
#    'id': 'b36d9b09-dc05-422c-997e-4e81b02afd6f',
#    'name': 'educ'},
#   {'display_name': {'fr': 'Régions et villes',
#     'de': 'Regionen und Städte',
#     'en': 'Regions and cities',
#     'it': 'Regioni e città'},
#    'description': {'fr': '', 'de': '', 'en': '', 'it': ''},
#    'title': '{"de": "Regionen und Städte", "en": "Regions and cities", "fr": "Régions et villes", "it": "Regioni e città"}',
#    'image_display_url': '',
#    'id': '5ce2de34-4114-43cd-ab45-e90a42db50aa',
#    'name': 'regi'}],
#  'issued': '2011-04-15T00:00:00',
#  'title_for_slug': 'bevolkerung',
#  'qualified_relations': [{'had_role': 'http://www.iana.org/assignments/relation/related',
#    'relation': 'https://ckan.opendata.swiss/perma/d513e0df-0c8a-4fad-9977-413478bfd3cb@kanton-basel-stadt'}],
#  'private': False,
#  'maintainer_email': 'stata@bs.ch',
#  'num_tags': 0,
#  'contact_points': [{'email': 'stata@bs.ch', 'name': 'stata@bs.ch'}],
#  'keywords': {'fr': ['repartition-de-la-population--demographie',
#    'aspects-sociaux-population',
#    'structure-de-la-population',
#    'mouvement-de-population'],
#   'de': ['verteilung-der-bevolkerung--demografie',
#    'soziale-aspekte-bevolkerung',
#    'bevolkerungsstruktur',
#    'bevolkerungsbewegung'],
#   'en': ['population-distribution--demography',
#    'social-aspects-population',
#    'population-structure',
#    'population-movement'],
#   'it': ['distribuzione-della-popolazione--demografia',
#    'aspetti-sociali-popolazione',
#    'struttura-della-popolazione',
#    'movimento-di-popolazioni']},
#  'temporals': [],
#  'id': 'a516dc66-def9-4043-bb1c-e9745ee70d5e',
#  'metadata_created': '2021-09-03T09:12:20.801963',
#  'conforms_to': [],
#  'metadata_modified': '2023-12-07T01:26:24.680552',
#  'author': None,
#  'author_email': None,
#  'isopen': False,
#  'relations': [{'url': 'http://map.geo.bs.ch/',
#    'label': 'Öffentliches Auskunftssystem des Kantons Basel-Stadt'},
#   {'url': 'https://www.geocat.ch/geonetwork/srv/ger/catalog.search#/metadata/726daf9f-935f-43e9-bc7a-c1d29c181764',
#    'label': 'geocat.ch permalink'}],
#  'state': 'active',
#  'version': None,
#  'relationships_as_object': [],
#  'license_id': None,
#  'see_alsos': [],
#  'type': 'dataset',
#  'resources': [{'protocol': 'WWW:DOWNLOAD-APP',
#    'cache_last_updated': None,
#    'issued': '2011-04-15T00:00:00',
#    'package_id': 'a516dc66-def9-4043-bb1c-e9745ee70d5e',
#    'datastore_contains_all_records_of_source_file': False,
#    'datastore_active': False,
#    'id': 'f595d523-9572-474d-8492-1598f32d81a9',
#    'size': None,
#    'display_name': {'fr': '', 'de': 'Geodaten-Shop', 'en': '', 'it': ''},
#    'title': {'fr': '', 'de': 'Geodaten-Shop', 'en': '', 'it': ''},
#    'created': '2022-06-13T11:36:26.086722',
#    'state': 'active',
#    'media_type': '',
#    'hash': '',
#    'description': {'fr': '',
#     'de': 'Öffentlich zugänglicher Geodaten-Downloaddienst des Kantons Basel-Stadt',
#     'en': '',
#     'it': ''},
#    'format': 'SERVICE',
#    'language': ['de'],
#    'mimetype_inner': None,
#    'url_type': None,
#    'mimetype': None,
#    'cache_url': None,
#    'name': {'fr': '', 'de': 'Geodaten-Shop', 'en': '', 'it': ''},
#    'license': 'NonCommercialAllowed-CommercialWithPermission-ReferenceRequired',
#    'rights': 'NonCommercialAllowed-CommercialWithPermission-ReferenceRequired',
#    'url': 'http://shop.geo.bs.ch/',
#    'byte_size': 0,
#    'modified': '',
#    'last_modified': None,
#    'position': 0,
#    'revision_id': '8bbefd5d-ffe1-4b3d-b646-4e365d8e0d9f',
#    'resource_type': None},
#   {'protocol': 'OGC:WMS',
#    'cache_last_updated': None,
#    'issued': '2011-04-15T00:00:00',
#    'package_id': 'a516dc66-def9-4043-bb1c-e9745ee70d5e',
#    'datastore_contains_all_records_of_source_file': False,
#    'datastore_active': False,
#    'id': '78538c0f-be06-4ee7-830f-b3e3747b4865',
#    'size': None,
#    'display_name': {'fr': '', 'de': 'WMS BS', 'en': '', 'it': ''},
#    'title': {'fr': '', 'de': 'WMS BS', 'en': '', 'it': ''},
#    'created': '2022-06-13T11:36:26.086731',
#    'state': 'active',
#    'media_type': '',
#    'hash': '',
#    'description': {'fr': '',
#     'de': 'Die derzeit im WMS BS verfügbaren Datenebenen entsprechen, bis auf wenige Ausnahmen, den Geodaten, welche auch in MapBS dargestellt sind. Der WMS BS ist kostenlos nutzbar und bietet Zugriff auf öffentliche sowie beschränkt öffentliche Geodaten, wobei gegebenenfalls Benutzername und Passwort benötigt werden (Zugangsdaten von MapBS).',
#     'en': '',
#     'it': ''},
#    'format': 'WMS',
#    'language': ['de'],
#    'mimetype_inner': None,
#    'url_type': None,
#    'mimetype': None,
#    'cache_url': None,
#    'name': {'fr': '', 'de': 'WMS BS', 'en': '', 'it': ''},
#    'license': 'NonCommercialAllowed-CommercialWithPermission-ReferenceRequired',
#    'rights': 'NonCommercialAllowed-CommercialWithPermission-ReferenceRequired',
#    'url': 'https://wms.geo.bs.ch/?SERVICE=wms&REQUEST=GetCapabilities',
#    'byte_size': 0,
#    'modified': '',
#    'last_modified': None,
#    'position': 1,
#    'revision_id': '8bbefd5d-ffe1-4b3d-b646-4e365d8e0d9f',
#    'resource_type': None},
#   {'protocol': 'OGC:WFS',
#    'cache_last_updated': None,
#    'issued': '2011-04-15T00:00:00',
#    'package_id': 'a516dc66-def9-4043-bb1c-e9745ee70d5e',
#    'datastore_contains_all_records_of_source_file': False,
#    'datastore_active': False,
#    'id': '4a1062f5-641a-48c3-9503-66a7da719032',
#    'size': None,
#    'display_name': {'fr': '', 'de': 'WFS BS', 'en': '', 'it': ''},
#    'title': {'fr': '', 'de': 'WFS BS', 'en': '', 'it': ''},
#    'created': '2022-06-13T11:36:26.086733',
#    'state': 'active',
#    'media_type': '',
#    'hash': '',
#    'description': {'fr': '',
#     'de': 'Die derzeit im WFS BS verfügbaren Datenebenen entsprechen, bis auf wenige Ausnahmen, den Geodaten, welche auch in MapBS dargestellt sind. Der WFS BS ist kostenlos nutzbar und bietet Zugriff auf öffentliche sowie beschränkt öffentliche Geodaten, wobei gegebenenfalls Benutzername und Passwort benötigt werden (Zugangsdaten von MapBS).',
#     'en': '',
#     'it': ''},
#    'format': 'WFS',
#    'language': ['de'],
#    'mimetype_inner': None,
#    'url_type': None,
#    'mimetype': None,
#    'cache_url': None,
#    'name': {'fr': '', 'de': 'WFS BS', 'en': '', 'it': ''},
#    'license': 'NonCommercialAllowed-CommercialWithPermission-ReferenceRequired',
#    'rights': 'NonCommercialAllowed-CommercialWithPermission-ReferenceRequired',
#    'url': 'https://wfs.geo.bs.ch/?SERVICE=wfs&REQUEST=GetCapabilities',
#    'byte_size': 0,
#    'modified': '',
#    'last_modified': None,
#    'position': 2,
#    'revision_id': '8bbefd5d-ffe1-4b3d-b646-4e365d8e0d9f',
#    'resource_type': None}],
#  'num_resources': 3,
#  'description': {'fr': '',
#   'de': 'Jugendlichenanteil: Anteil der unter 20-jährigen Personen an der Gesamtbevölkerung. Seniorenanteil: Anteil der über 64-jährigen Personen an der Gesamtbevölkerung. Sesshaftigkeit: Anteil der seit mindestens 10 Jahren am gleichen Wohnort lebenden Personen an der Gesamtbevölkerung. Ausländeranteil: Anteil der Ausländer an der Gesamtbevölkerung.',
#   'en': '',
#   'it': ''},
#  'tags': [],
#  'spatial': 'Kanton Basel-Stadt (BS)',
#  'coverage': '',
#  'creator_user_id': 'af084126-f711-4016-a585-70354e997796',
#  'display_name': {},
#  'relationships_as_subject': [],
#  'publisher': '{"url": "http://www.statistik.bs.ch", "name": "Kanton Basel-Stadt"}',
#  'organization': {'display_name': {'fr': 'Canton de Bâle-Ville',
#    'de': 'Kanton Basel-Stadt',
#    'en': 'Canton of Basel-City',
#    'it': 'Cantone di Basilea-Città'},
#   'description': {'fr': '',
#    'en': '',
#    'de': 'Der Kanton Basel-Stadt veröffentlicht nach und nach Open Government-Datensätze von kantonalen Ämtern und Dienststellen. Die kantonale Fachstelle für Open Government Data ist als Koordinationsorgan zuständig für die Unterstützung der datenpublizierenden Verwaltungsstellen. ',
#    'it': ''},
#   'name': 'kanton-basel-stadt',
#   'image_display_url': 'https://ckan.opendata.swiss/uploads/group/BS_Logo_bs_A4.png',
#   'url': 'https://www.opendata.bs.ch',
#   'package_count': 413,
#   'created': '2016-03-03T15:56:49.710722',
#   'political_level': 'canton',
#   'is_organization': True,
#   'state': 'active',
#   'image_url': 'https://ckan.opendata.swiss/uploads/group/BS_Logo_bs_A4.png',
#   'groups': [],
#   'type': 'organization',
#   'title': {'fr': 'Canton de Bâle-Ville',
#    'de': 'Kanton Basel-Stadt',
#    'en': 'Canton of Basel-City',
#    'it': 'Cantone di Basilea-Città'},
#   'revision_id': '81440e04-20c2-497b-89ed-cab0aab8dc9a',
#   'num_followers': 0,
#   'id': 'bc3fde05-b0bf-4035-a098-a2d6f89d47c3',
#   'tags': [],
#   'approval_status': 'approved'},
#  'name': 'bevolkerung',
#  'language': ['de'],
#  'accrual_periodicity': 'http://publications.europa.eu/resource/authority/frequency/ANNUAL',
#  'license_title': None,
#  'modified': '',
#  'url': 'http://map.geo.bs.ch/',
#  'extras': [{'key': 'harvest_object_id',
#    'value': '3e200645-9a82-4380-b38a-d26d2eaf9cc2'},
#   {'key': 'harvest_source_id',
#    'value': '978745ac-582e-4ea2-820c-f537ae72a432'},
#   {'key': 'harvest_source_title', 'value': 'BS - Geocat Harvester'}],
#  'title': {'fr': '', 'de': 'Bevölkerung', 'en': '', 'it': ''},
#  'revision_id': 'd0bcc61e-b954-46b4-9ae4-c1e6d1d40688',
#  'identifier': '726daf9f-935f-43e9-bc7a-c1d29c181764@kanton-basel-stadt'}
